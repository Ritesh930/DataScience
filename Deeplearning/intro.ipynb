# %% [markdown]
# deep leaning---
#
# ANN--artificial neural networks
# input layer-hidden layer-output layer
#
# nodes in:-
#
#    input layer are no. of independent variables
#    output layer definde using two things---
#                                             1. Binary classification--yes/no, 0/1
#                                             2.multiclass classification-- classify 2 se jyada win or loss

# %%
#  functions
#  
#  d for binary classification
#  tangent-used for regression 
#  cycle completion of forward and backward propagation
#  te--how fast the model learns
